# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("test_preprocessing_output_qab.csv")
df
# Out:
#                                                    text  \
# 0                              Il est aussi philologue.
# 1                          l'article Matrice par blocs)
# 2     Paul Jules Antoine Meillet, né le à Moulins (A...
# 3     D'origine bourbonnaise, fils d'un notaire de C...
# 4     Étudiant à la faculté des lettres de Paris à p...
# ...                                                 ...
# 7321  Even if some of them offer instruction in Arab...
# 7322  Among the most important universities, there a...
# 7323  The University of Abou Bekr Belkaïd in Tlemcen...
# 7324  This is a list of characters in Ayn Rand's nov...
# 7325  The following are major characters from the no...
#
#                                                    meta  \
# 0     {'title': 'Antoine Meillet', 'docid': '3#0', '...
# 1     {'title': 'Algèbre linéaire', 'docid': '7#8', ...
# 2     {'title': 'Antoine Meillet', 'docid': '3#0', '...
# 3     {'title': 'Antoine Meillet', 'docid': '3#1', '...
# ...
