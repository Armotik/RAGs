# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("test_preprocessing_output_qab.csv")
df
# Out:
#                                                    text  \
# 0     Paul Jules Antoine Meillet, né le à Moulins (A...
# 1                              Il est aussi philologue.
# 2     D'origine bourbonnaise, fils d'un notaire de C...
# 3     Étudiant à la faculté des lettres de Paris à p...
# 4     En 1889, il est major de l'agrégation de gramm...
# ...                                                 ...
# 7321  Even if some of them offer instruction in Arab...
# 7322  Among the most important universities, there a...
# 7323  The University of Abou Bekr Belkaïd in Tlemcen...
# 7324  This is a list of characters in Ayn Rand's nov...
# 7325  The following are major characters from the no...
#
#                                                    meta  \
# 0     {'title': 'Antoine Meillet', 'docid': '3#0', '...
# 1     {'title': 'Antoine Meillet', 'docid': '3#0', '...
# 2     {'title': 'Antoine Meillet', 'docid': '3#1', '...
# 3     {'title': 'Antoine Meillet', 'docid': '3#2', '...
# 4     {'title': 'Antoine Meillet', 'docid': '3#3', '...
# ...                                                 ...
# 7321  {'title': 'Algeria', 'docid': '358#136', 'lang...
# 7322  {'title': 'Algeria', 'docid': '358#136', 'lang...
# 7323  {'title': 'Algeria', 'docid': '358#136', 'lang...
# 7324  {'title': 'List of Atlas Shrugged characters',...
# 7325  {'title': 'List of Atlas Shrugged characters',...
#
#                                            text_segment  \
# 0     Paul Jules Antoine Meillet, né le à Moulins (A...
# 1                              Il est aussi philologue.
# 2     D'origine bourbonnaise, fils d'un notaire de C...
# 3     Étudiant à la faculté des lettres de Paris à p...
# 4     En 1889, il est major de l'agrégation de gramm...
# ...                                                 ...
# 7321  Even if some of them offer instruction in Arab...
# 7322  Among the most important universities, there a...
# 7323  The University of Abou Bekr Belkaïd in Tlemcen...
# 7324  This is a list of characters in Ayn Rand's nov...
# 7325  The following are major characters from the no...
#
#                                   title  \
# 0                       Antoine Meillet
# 1                       Antoine Meillet
# 2                       Antoine Meillet
# 3                       Antoine Meillet
# 4                       Antoine Meillet
# ...                                 ...
# 7321                            Algeria
# 7322                            Algeria
# 7323                            Algeria
# 7324  List of Atlas Shrugged characters
# 7325  List of Atlas Shrugged characters
#
#                                                entities lang  \
# 0     [('Paul Jules Antoine Meillet', 'PER'), ('Moul...   fr
# 1                                   [('philo', 'MISC')]   fr
# 2     [('Châteaumeillant', 'LOC'), ('Cher', 'LOC'), ...   fr
# 3     [('Paris', 'LOC'), ('Louis Havet', 'PER'), ('M...   fr
# 4                               [('grammaire', 'MISC')]   fr
# ...                                                 ...  ...
# 7321  [('Arabic', 'MISC'), ('French', 'MISC'), ('Eng...   en
# 7322  [('University of Sciences and Technology Houar...   en
# 7323  [('University of Abou Bekr Belkaïd', 'ORG'), (...   en
# 7324  [('Ayn Rand', 'PER'), ('Atlas Shrugged', 'MISC')]   en
# 7325                                                 []   en
#
#                                      generated_question  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7321  What languages are most sectors in Algeria pro...
# 7322  Which universities are among the most importan...
# 7323  Which university in Algeria ranks 26th in Africa?
# 7324               Who is the author of Atlas Shrugged?
# 7325  Who are the main characters in the novel "Atla...
#
#                                        generated_answer  llm_confidence  \
# 0                                                   NaN             NaN
# 1                                                   NaN             NaN
# 2                                                   NaN             NaN
# 3                                                   NaN             NaN
# 4                                                   NaN             NaN
# ...                                                 ...             ...
# 7321                                 French and English             1.0
# 7322  The University of Sciences and Technology Houa...             1.0
# 7323  The University of Abou Bekr Belkaïd in Tlemcen...             1.0
# 7324                                           Ayn Rand             1.0
# 7325  The main characters in the novel "Atlas Shrugg...             1.0
#
#       bert_score_f1                               error_qab_generation  \
# 0            0.0000  CUDA out of memory. Tried to allocate 9.28 GiB...
# 1            0.0000  CUDA out of memory. Tried to allocate 9.28 GiB...
# 2            0.0000  CUDA out of memory. Tried to allocate 9.28 GiB...
# 3            0.0000  CUDA out of memory. Tried to allocate 9.28 GiB...
# 4            0.0000  CUDA out of memory. Tried to allocate 9.28 GiB...
# ...             ...                                                ...
# 7321         0.7295                                                NaN
# 7322         0.9034                                                NaN
# 7323         0.8939                                                NaN
# 7324         0.6525                                                NaN
# 7325         0.7027                                                NaN
#
#       error_bertscore
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 7321              NaN
# 7322              NaN
# 7323              NaN
# 7324              NaN
# 7325              NaN
#
# [7326 rows x 12 columns]
