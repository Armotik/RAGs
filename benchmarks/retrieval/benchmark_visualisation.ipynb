# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

# %%
df = pd.read_csv('benchmark.csv')
df
# Out:
#                             model  device  cosine@1_dense  mean@5_dense  \
# 0              Linq-Embed-Mistral  cuda:1          0.5957        0.5804
# 1           SFR-Embedding-Mistral  cuda:1          0.6981        0.6609
# 2  multilingual-e5-large-instruct  cuda:0          0.8693        0.8512
# 3          e5-mistral-7b-instruct  cuda:0          0.7232        0.6929
#
#    drop_1to2_dense  cosine@1_fusion  mean@5_fusion  drop_1to2_fusion  time(s)
# 0           0.0109           0.6101         0.5887            0.0144  58.2125
# 1           0.0337           0.6981         0.6747            0.0186  32.0129
# 2           0.0151           0.8693         0.8530            0.0151  16.6130
# 3           0.0203           0.7232         0.7020            0.0203  26.7413
